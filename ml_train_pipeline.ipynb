# %%
from ml_models_regression import *

train_features = pd.read_csv("../train_test_val_split/train_features.csv") 
train_labels = pd.read_csv("../train_test_val_split/train_labels.csv",header=None)

# %%
model = Ml_models_regression(train_features, train_labels, 'r2')

# %%
#model.polynomial_regression()
#model.linear_regression()
#model.ridge_regression()
#model.elasticnet_regression()
#model.lasso_regression()
#model.decision_trees_regressor()
model.gradient_boosting_regressor()
model.xgboosting_regressor()
model.random_forest_regressor()
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START learning_rate=0.01, max_depth=16, n_estimators=100.........
# [CV 1/5; 1/24] END learning_rate=0.01, max_depth=16, n_estimators=100;, score=0.077 total time=  18.7s
# [CV 2/5; 1/24] START learning_rate=0.01, max_depth=16, n_estimators=100.........
# [CV 2/5; 1/24] END learning_rate=0.01, max_depth=16, n_estimators=100;, score=0.123 total time=  19.5s
# [CV 3/5; 1/24] START learning_rate=0.01, max_depth=16, n_estimators=100.........
# [CV 3/5; 1/24] END learning_rate=0.01, max_depth=16, n_estimators=100;, score=0.081 total time=  19.4s
# [CV 4/5; 1/24] START learning_rate=0.01, max_depth=16, n_estimators=100.........
# [CV 4/5; 1/24] END learning_rate=0.01, max_depth=16, n_estimators=100;, score=0.120 total time=  19.7s
# [CV 5/5; 1/24] START learning_rate=0.01, max_depth=16, n_estimators=100.........
# ...
